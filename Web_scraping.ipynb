# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarshan-360/Machine-Learning/blob/main/Web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 lxml pandas

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from datetime import datetime
import time

headers = {
    "User-Agent": "Mozilla/5.0"
}
def get_product_links(base_url, max_pages=3):
    links = []
    for page in range(1, max_pages + 1):
        url = f"{base_url}?p={page}"
        print(f"🔗 Scanning: {url}")
        r = requests.get(url, headers=headers)
        soup = BeautifulSoup(r.content, "lxml")

        for a in soup.select("a.product-item-link"):
            href = a.get("href")
            if href and href.startswith("https"):
                links.append(href)
        time.sleep(1)
    return list(set(links))

def extract_saree_info(url):
    try:
        r = requests.get(url, headers=headers)
        soup = BeautifulSoup(r.content, "lxml")

        name = soup.select_one("h1.page-title")
        name = name.text.strip() if name else "Not Found"

        price = soup.select_one("span.price")
        price = price.text.strip() if price else "Not Found"

        specs = {
            tr.find("th").text.strip(): tr.find("td").text.strip()
            for tr in soup.select("table.data.table.additional-attributes tbody tr")
        }

        fabric = specs.get("Material", "Not Found")
        color = specs.get("Color", "Not Found")
        border = specs.get("Border") or specs.get("Border Type") or "Not Found"
        blouse = specs.get("Blouse Color", "Not Found")

        desc = soup.select_one(".product.attribute.description")
        description_text = desc.text.strip() if desc else ""

        occasion_match = re.search(r"(wedding|casual|festive|formal|party)", description_text, re.IGNORECASE)
        occasion = occasion_match.group(0).capitalize() if occasion_match else "Not Mentioned"

        pallu_match = re.search(r"(pallu.*?)\.", description_text, re.IGNORECASE)
        pallu = pallu_match.group(0).strip() if pallu_match else "Not Mentioned"

        img = soup.select_one("img.fotorama__img")
        img_url = img.get("src") if img else "Not Found"

        return {
            "Name": name,
            "Price": price,
            "Base Color": color,
            "Fabric Type": fabric,
            "Border Type": border,
            "Blouse Color": blouse,
            "Occasion": occasion,
            "Pallu": pallu,
            "Image URL": img_url,
            "Product URL": url
        }

    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None


# Use your favorite category — change this link if needed
category_url = "https://www.nalli.com/woman/saree/kanchipuram"
product_links = get_product_links(category_url, max_pages=100)

print(f"\n🔍 Found {len(product_links)} product pages.\nScraping now...")

sarees = [extract_saree_info(link) for link in product_links]
sarees = [s for s in sarees if s is not None]

# Save to CSV
df = pd.DataFrame(sarees)
filename = f"nalli_saree_dataset_{datetime.now().strftime('%Y-%m-%d')}.csv"
df.to_csv(filename, index=False)

print("✅ DONE! Saved as", filename)
df.head()
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=1
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=2
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=3
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=4
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=5
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=6
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=7
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=8
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=9
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=10
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=11
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=12
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=13
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=14
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=15
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=16
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=17
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=18
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=19
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=20
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=21
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=22
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=23
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=24
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=25
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=26
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=27
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=28
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=29
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=30
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=31
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=32
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=33
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=34
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=35
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=36
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=37
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=38
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=39
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=40
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=41
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=42
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=43
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=44
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=45
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=46
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=47
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=48
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=49
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=50
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=51
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=52
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=53
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=54
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=55
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=56
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=57
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=58
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=59
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=60
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=61
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=62
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=63
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=64
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=65
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=66
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=67
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=68
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=69
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=70
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=71
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=72
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=73
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=74
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=75
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=76
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=77
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=78
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=79
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=80
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=81
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=82
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=83
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=84
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=85
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=86
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=87
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=88
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=89
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=90
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=91
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=92
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=93
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=94
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=95
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=96
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=97
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=98
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=99
# 🔗 Scanning: https://www.nalli.com/woman/saree/kanchipuram?p=100
#
# 🔍 Found 3326 product pages.
# Scraping now...
# ✅ DONE! Saved as nalli_saree_dataset_2025-07-19.csv
#                                                 Name       Price Base Color  \
# 0       Pure Silk Pure Zari Orange Kanchipuram Saree  ₹46,145.00     Orange
# 1  Pure Silk Pure Zari Purple Dual Tone Kanchipur...  ₹39,270.00     Purple
# 2             Brown Dual Tone Kanchipuram Silk Saree   ₹8,055.00      Brown
# 3  Pure Silk Pure Zari Orange Dual Tone Kanchipur...  ₹47,068.00     Orange
# 4                      Maroon Kanchipuram Silk Saree  ₹17,145.00     Maroon
#
#   Fabric Type          Border Type Blouse Color       Occasion          Pallu  \
# 0        Silk          Zari Border       Purple  Not Mentioned  Not Mentioned
# 1        Silk         Fancy Border       Purple  Not Mentioned  Not Mentioned
# 2        Silk          Zari Border          Red  Not Mentioned  Not Mentioned
# 3        Silk          Zari Border    Sea Green  Not Mentioned  Not Mentioned
# 4        Silk  Ganga Jamuna Border       Maroon  Not Mentioned  Not Mentioned
#
#    Image URL                                        Product URL
# 0  Not Found  https://www.nalli.com/orange-kanchipuram-silk-...
# 1  Not Found  https://www.nalli.com/purple-dual-tone-kanchip...
# 2  Not Found  https://www.nalli.com/brown-dual-tone-kanchipu...
# 3  Not Found  https://www.nalli.com/orange-dual-tone-kanchip...
# 4  Not Found  https://www.nalli.com/maroon-kanchipuram-silk-...

# %%
print("Number of rows (excluding header):", len(df))
print("Number of columns:", len(df.columns))
# Out:
# Number of rows (excluding header): 3326
# Number of columns: 10

# %%
from google.colab import files
files.download("nalli_saree_dataset_2025-07-19.csv")
